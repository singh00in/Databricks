# %%
# this note book is being called in the Job where X and Y is pass as parameter and the value of Z is returned by the exit function 
dbutils.widgets.text("x", "")
dbutils.widgets.text("y", "")
x=dbutils.widgets.get("x")
y=dbutils.widgets.get("y")
z=x+y
#print(z)
## below command will pass the value to parent notebook as exit value success
#
dbutils.notebook.exit(z)
